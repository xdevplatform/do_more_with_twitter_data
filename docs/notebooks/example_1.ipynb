# %% [markdown]
# # Doing a thing With A Heading
#
# Hi, this is an example jupyter notebook.

# %%
import os
import pandas as pd

# %% [markdown]
# ## Subheading 1

# %%
df = pd.read_csv('https://download.bls.gov/pub/time.series/cu/cu.item',
                 sep='\t')

# %%
df.head()
# Out:
#                                                item_code  item_name  \
# AA0                                 All items - old base          0
# AA0R   Purchasing power of the consumer dollar - old ...          0
# SA0                                            All items          0
# SA0E                                              Energy          1
# SA0L1                                All items less food          1
#
#       display_level  selectable  sort_sequence
# AA0               T           2            NaN
# AA0R              T         399            NaN
# SA0               T           1            NaN
# SA0E              T         374            NaN
# SA0L1             T         358            NaN

# %% [markdown]
# ### Subheading 2
#
# Words and phrases

# %%
df.query("item_name == 0")
# Out:
#                                               item_code  item_name  \
# AA0                                All items - old base          0
# AA0R  Purchasing power of the consumer dollar - old ...          0
# SA0                                           All items          0
# SA0R            Purchasing power of the consumer dollar          0
# SAA                                             Apparel          0
# SAE                         Education and communication          0
# SAF                                  Food and beverages          0
# SAG                            Other goods and services          0
# SAH                                             Housing          0
# SAM                                        Medical care          0
# SAR                                          Recreation          0
# SAT                                      Transportation          0
#
#      display_level  selectable  sort_sequence
# AA0              T           2            NaN
# AA0R             T         399            NaN
# SA0              T           1            NaN
# SA0R             T         398            NaN
# SAA              T         187            NaN
# SAE              T         311            NaN
# SAF              T           3            NaN
# SAG              T         335            NaN
# SAH              T         136            NaN
# SAM              T         250            NaN
# SAR              T         269            NaN
# SAT              T         210            NaN

# %% [markdown]
# #### Subheading 3
#
# sub sub sub sub sub
#
#
# $$ \forall x \in \mathbb{R} $$
